# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/home/schiavazza/code/hpe/vicon_recordings/data/frame.png')

# %%
plt.imshow(img)

# %%
import yaml

# %%
with open("/home/schiavazza/code/hpe/vicon_recordings/data/points.yml", "r") as stream:
    try:
        data = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)

# %%
for i, l in enumerate(data):
    p = data[l]
    print(l)
    cv2.circle(img, (p['x'], p['y']), 5, (255, 30 * i, 0), -1)
# Out:
# RASI
# LASI
# STRN
# CLAV
# RFHD
# LFHD
# LSHO
# RSHO

# %%
plt.imshow(img)
